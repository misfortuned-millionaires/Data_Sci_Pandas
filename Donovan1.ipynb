# %% [markdown]
# # Donovan Brown
# ## "Phases of Analysis and Visualization"

# %% [markdown]
# 1. Gathering data
# 2. Cleaning the data
# 3. Preparing the data
# 4. Analyzing the data
# 5. Visualizing the data

# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
poll_url = 'http://projects.fivethirtyeight.com/general-model/president_general_polls_2016.csv'
polls = pd.read_csv(poll_url)

# %%
polls.sort_values('state', inplace=True)
polls.head()
# Out:
#        cycle     branch        type                        matchup  \
# 12475   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 3165    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3304    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9971    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8387    2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 12475      11/8/16  Alabama  10/21/2016   11/2/2016                    Ipsos
# 3165       11/8/16  Alabama   8/24/2016   8/30/2016  Google Consumer Surveys
# 3304       11/8/16  Alabama   7/29/2016   8/18/2016                    Ipsos
# 9971       11/8/16  Alabama   9/30/2016  10/20/2016                    Ipsos
# 8387       11/8/16  Alabama   9/30/2016  10/13/2016                    Ipsos
#
#       grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 12475    A-  ...         40.48323      53.28125              NaN
# 3165      B  ...         24.57778      64.97036         3.560686
# 3304     A-  ...         35.64400      56.35091              NaN
# 9971     A-  ...         37.21149      53.39428              NaN
# 8387     A-  ...         37.25122      54.81887              NaN
#
#        adjpoll_mcmullin  multiversions  \
# 12475               NaN            NaN
# 3165                NaN            NaN
# 3304                NaN            NaN
# 9971                NaN            NaN
# 8387                NaN            NaN
#
#                                                      url  poll_id  \
# 12475          http://www.reuters.com/statesofthenation/    48213
# 3165   https://drive.google.com/drive/u/0/folders/0B2...    45491
# 3304            http://www.reuters.com/statesofthenation    44940
# 9971           http://www.reuters.com/statesofthenation/    47185
# 8387               http://reuters.com/statesofthenation/    46817
#
#        question_id  createddate             timestamp
# 12475        75514      11/3/16  09:14:14  8 Nov 2016
# 3165         70809       9/9/16  09:35:33  8 Nov 2016
# 3304         68973      8/24/16  09:35:33  8 Nov 2016
# 9971         73862     10/22/16  09:14:14  8 Nov 2016
# 8387         73263     10/15/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Use Tab completion and tooltips

# %%
polls.sort_values('state', ascending=False).head()
# Out:
#       cycle     branch        type                        matchup  \
# 5595   2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 6453   2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 1110   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 9752   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 2788   2016  President  polls-plus  Clinton vs. Trump vs. Johnson
#
#      forecastdate    state   startdate     enddate                 pollster  \
# 5595      11/8/16  Wyoming  10/24/2016  10/30/2016             SurveyMonkey
# 6453      11/8/16  Wyoming   9/27/2016   10/3/2016  Google Consumer Surveys
# 1110      11/8/16  Wyoming  10/20/2016  10/24/2016  Google Consumer Surveys
# 9752      11/8/16  Wyoming  10/25/2016  10/31/2016             SurveyMonkey
# 2788      11/8/16  Wyoming   8/24/2016   8/30/2016  Google Consumer Surveys
#
#      grade  ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  \
# 5595    C-  ...         21.66060      62.70650         4.911339
# 6453     B  ...         25.57931      43.88375         6.331504
# 1110     B  ...         26.13374      60.67764         7.875940
# 9752    C-  ...         20.65567      62.55081         7.020044
# 2788     B  ...         29.24886      51.94522         5.180686
#
#       adjpoll_mcmullin  multiversions  \
# 5595               NaN            NaN
# 6453               NaN            NaN
# 1110               NaN            NaN
# 9752               NaN            NaN
# 2788               NaN            NaN
#
#                                                     url  poll_id  question_id  \
# 5595  https://www.surveymonkey.com/elections/map?pol...    47844        74867
# 6453  https://datastudio.google.com/u/0/#/org//repor...    46509        72707
# 1110  https://datastudio.google.com/u/0/#/org//repor...    47406        74443
# 9752  https://www.surveymonkey.com/elections/map?pol...    47933        74989
# 2788  https://drive.google.com/drive/u/0/folders/0B2...    45540        70925
#
#       createddate             timestamp
# 5595     10/31/16  09:24:53  8 Nov 2016
# 6453      10/5/16  09:24:53  8 Nov 2016
# 1110     10/27/16  09:35:33  8 Nov 2016
# 9752      11/1/16  09:14:14  8 Nov 2016
# 2788       9/9/16  09:35:33  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Clean the data

# %% [markdown]
# ### Keep only the rows with "now-cast" in the type column

# %%
polls = polls.query('type=="now-cast"')
polls.head()
# Out:
#       cycle     branch      type                        matchup forecastdate  \
# 8387   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state   startdate     enddate                 pollster grade  ...  \
# 8387  Alabama   9/30/2016  10/13/2016                    Ipsos    A-  ...
# 7434  Alabama   7/29/2016   8/18/2016                    Ipsos    A-  ...
# 7628  Alabama   8/10/2016   8/16/2016  Google Consumer Surveys     B  ...
# 6238  Alabama  10/10/2016  10/14/2016  Google Consumer Surveys     B  ...
# 7142  Alabama    9/7/2016   9/13/2016  Google Consumer Surveys     B  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 8387         37.25122      54.81887              NaN               NaN
# 7434         36.01944      56.00800              NaN               NaN
# 7628         26.73066      63.84499         1.497811               NaN
# 6238         25.17749      63.12038         2.313444               NaN
# 7142         26.38999      65.16069         0.851151               NaN
#
#       multiversions                                                url  \
# 8387            NaN              http://reuters.com/statesofthenation/
# 7434            NaN           http://www.reuters.com/statesofthenation
# 7628            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6238            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7142            NaN  https://drive.google.com/drive/u/0/folders/0B2...
#
#       poll_id  question_id  createddate             timestamp
# 8387    46817        73263     10/15/16  09:24:53  8 Nov 2016
# 7434    44940        68973      8/24/16  09:24:53  8 Nov 2016
# 7628    45592        70977       9/9/16  09:24:53  8 Nov 2016
# 6238    46957        73446     10/17/16  09:24:53  8 Nov 2016
# 7142    45743        71427      9/14/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Rename voting columns

# %%
polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
                      'rawpoll_trump':'Trump_pct'},inplace=True)
polls.head()
# Out:
# /var/folders/09/j9pq4k6934g549gvvm6bl5vc0000gn/T/ipykernel_15521/4063675258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls.rename(columns={'rawpoll_clinton':'Clinton_pct',
#       cycle     branch      type                        matchup forecastdate  \
# 8387   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 8387  Alabama 2016-09-30 2016-10-13                    Ipsos    A-  ...
# 7434  Alabama 2016-07-29 2016-08-18                    Ipsos    A-  ...
# 7628  Alabama 2016-08-10 2016-08-16  Google Consumer Surveys     B  ...
# 6238  Alabama 2016-10-10 2016-10-14  Google Consumer Surveys     B  ...
# 7142  Alabama 2016-09-07 2016-09-13  Google Consumer Surveys     B  ...
#
#       Clinton_pct Trump_pct  adjpoll_johnson  adjpoll_mcmullin  multiversions  \
# 8387     37.25122  54.81887              NaN               NaN            NaN
# 7434     36.01944  56.00800              NaN               NaN            NaN
# 7628     26.73066  63.84499         1.497811               NaN            NaN
# 6238     25.17749  63.12038         2.313444               NaN            NaN
# 7142     26.38999  65.16069         0.851151               NaN            NaN
#
#                                                     url  poll_id  question_id  \
# 8387              http://reuters.com/statesofthenation/    46817        73263
# 7434           http://www.reuters.com/statesofthenation    44940        68973
# 7628  https://drive.google.com/drive/u/0/folders/0B2...    45592        70977
# 6238  https://datastudio.google.com/u/0/#/org//repor...    46957        73446
# 7142  https://drive.google.com/drive/u/0/folders/0B2...    45743        71427
#
#       createddate             timestamp
# 8387     10/15/16  09:24:53  8 Nov 2016
# 7434      8/24/16  09:24:53  8 Nov 2016
# 7628       9/9/16  09:24:53  8 Nov 2016
# 6238     10/17/16  09:24:53  8 Nov 2016
# 7142      9/14/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Convert date columns to datetime objects

# %%
date_cols = ["startdate","enddate"]
polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
polls.head()
# Out:
# /var/folders/09/j9pq4k6934g549gvvm6bl5vc0000gn/T/ipykernel_15521/732497925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polls[date_cols] = polls[date_cols].apply(pd.to_datetime)
#       cycle     branch      type                        matchup forecastdate  \
# 8387   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7434   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7628   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 6238   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
# 7142   2016  President  now-cast  Clinton vs. Trump vs. Johnson      11/8/16
#
#         state  startdate    enddate                 pollster grade  ...  \
# 8387  Alabama 2016-09-30 2016-10-13                    Ipsos    A-  ...
# 7434  Alabama 2016-07-29 2016-08-18                    Ipsos    A-  ...
# 7628  Alabama 2016-08-10 2016-08-16  Google Consumer Surveys     B  ...
# 6238  Alabama 2016-10-10 2016-10-14  Google Consumer Surveys     B  ...
# 7142  Alabama 2016-09-07 2016-09-13  Google Consumer Surveys     B  ...
#
#       adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# 8387         37.25122      54.81887              NaN               NaN
# 7434         36.01944      56.00800              NaN               NaN
# 7628         26.73066      63.84499         1.497811               NaN
# 6238         25.17749      63.12038         2.313444               NaN
# 7142         26.38999      65.16069         0.851151               NaN
#
#       multiversions                                                url  \
# 8387            NaN              http://reuters.com/statesofthenation/
# 7434            NaN           http://www.reuters.com/statesofthenation
# 7628            NaN  https://drive.google.com/drive/u/0/folders/0B2...
# 6238            NaN  https://datastudio.google.com/u/0/#/org//repor...
# 7142            NaN  https://drive.google.com/drive/u/0/folders/0B2...
#
#       poll_id  question_id  createddate             timestamp
# 8387    46817        73263     10/15/16  09:24:53  8 Nov 2016
# 7434    44940        68973      8/24/16  09:24:53  8 Nov 2016
# 7628    45592        70977       9/9/16  09:24:53  8 Nov 2016
# 6238    46957        73446     10/17/16  09:24:53  8 Nov 2016
# 7142    45743        71427      9/14/16  09:24:53  8 Nov 2016
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Try two plots

# %%
polls.plot.line(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# <Axes: xlabel='enddate'>

# %%
# %%time
polls.query('state == "U.S."') \
    .plot(x='enddate',y=['Clinton_pct','Trump_pct'])
# Out:
# CPU times: user 91.7 ms, sys: 5.96 ms, total: 97.6 ms
# Wall time: 123 ms
# <Axes: xlabel='enddate'>

# %%
# %whos
# Out:
# Variable          Type             Data/Info
# --------------------------------------------
# NamespaceMagics   MetaHasTraits    <class 'IPython.core.magi<...>mespace.NamespaceMagics'>
# date_cols         list             n=2
# get_ipython       function         <function get_ipython at 0x102041800>
# json              module           <module 'json' from '/opt<...>on3.11/json/__init__.py'>
# pd                module           <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# poll_url          str              http://projects.fivethirt<...>nt_general_polls_2016.csv
# polls             DataFrame              cycle     branch   <...>n[4208 rows x 27 columns]
# sys               module           <module 'sys' (built-in)>

# %%
type(polls)
# Out:
# pandas.core.frame.DataFrame
